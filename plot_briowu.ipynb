# %%
import numpy as np
import matplotlib.pyplot as plt
import linecache

# %%
filename = "output/briowu/grid"
x1 = np.array([float(i) for i in linecache.getline(filename, 1).split()])

filename = "output/briowu/st10"
data = np.loadtxt(filename, dtype=float, skiprows=1).T
rho = data[0]
vx = data[1]
vy = data[2]
vz = data[3]
p = data[4]
bx = data[5]
by = data[6]
bz = data[7]

# %%
plt.figure(figsize=(12, 10))
plt.plot(x1, rho) #, marker="o")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.plot(x1, p)
plt.show()
